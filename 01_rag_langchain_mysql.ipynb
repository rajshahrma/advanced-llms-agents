# %%
pip install langchain langchain_community langchain_text_splitters gemini-client
# Out:
# ...
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached ormsgpack-1.12.2-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# ...
# Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# ...
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.2 MB/s  0:00:00
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.8 MB/s  0:00:00
# ...
# Using cached ormsgpack-1.12.2-cp313-cp313-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# ...

# %%
import mysql.connector
    
# Connect to the database
import mysql.connector
# Connect to the database
mydb = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="root",
    database="rag_test",
    allow_local_infile=True,
    use_pure=True,
    autocommit=True,
)

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load the blog post
loader = WebBaseLoader(web_paths=("https://blog.langchain.com/deep-agents/",))
docs = loader.load()

# Split the document into chunks of 1000 characters with a 200-character overlap
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200) 
splits = text_splitter.split_documents(docs)
# Out:
# /var/folders/3k/0thdr6f968v5t6jr2wfhz89m0000gn/T/ipykernel_56312/1716004285.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
from mysql.ai.genai import MyEmbeddings, MyVectorStore
    
# Initialize the HeatWave Vector Store with an embedding model
vectorstore = MyVectorStore(mydb, MyEmbeddings(mydb))
# Add the document chunks to the store
vectorstore.add_documents(documents=splits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from mysql.ai.genai import MyEmbeddings, MyVectorStore
#       3 # Initialize the HeatWave Vector Store with an embedding model
# ----> 4 vectorstore = MyVectorStore(mydb, MyEmbeddings(mydb))
#       5 # Add the document chunks to the store
#       6 vectorstore.add_documents(documents=splits)
#
# NameError: name 'mydb' is not defined

# %%
import os

from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    GoogleGenerativeAIEmbeddings,
)

from langchain_community.vectorstores import FAISS

from langchain_community.document_loaders import PyPDFLoader

from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# /var/folders/3k/0thdr6f968v5t6jr2wfhz89m0000gn/T/ipykernel_74815/3858256203.py:8: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 12
#       8 from langchain_community.vectorstores import FAISS
#      10 from langchain_community.document_loaders import PyPDFLoader
# ---> 12 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
pip install -qU  langchain langchain-community  langchain-google-genai  faiss-cpu  pypdf
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    GoogleGenerativeAIEmbeddings,
)

from langchain_community.vectorstores import FAISS

from langchain_community.document_loaders import PyPDFLoader

from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 12
#       8 from langchain_community.vectorstores import FAISS
#      10 from langchain_community.document_loaders import PyPDFLoader
# ---> 12 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'
